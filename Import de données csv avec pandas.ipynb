# %%
import pandas as pd

# %% [markdown]
# ### création du dataframe `raw_data` à partir de "meteo_france.csv"
#
# Le séparateur est ';'

# %%
raw_data= pd.read_csv("meteo_france.csv", sep= ';')

# %%
raw_data.head()
# Out:
#                          id  \
# 0  560c27c188ee3807bc83905f
# 1  560c257888ee3807bc83905d
# 2  560c249c88ee386c51839066
# 3  560c0e4288ee38719e83905a
# 4  539a61d5a3a7293bc2728379
#
#                                                title  \
# 0  Indices annuels de précipitations et nombre de...
# 1  Indices saisonniers de température et nombre d...
# 2  Indices annuels de température et nombre de jo...
# 3  Indices mensuels d'anomalie de température et ...
# 4  Données horaires des 55 stations terrestres de...
#
#                                                 slug  \
# 0  indices-annuels-de-precipitations-et-nombre-de...
# 1  indices-saisonniers-de-temperature-et-nombre-d...
# 2  indices-annuels-de-temperature-et-nombre-de-jo...
# 3  indices-mensuels-danomalie-de-temperature-et-d...
# 4  donnees-horaires-des-55-stations-terrestres-de...
#
#                                                  url  organization  \
# 0  https://www.data.gouv.fr/fr/datasets/indices-a...  Météo-France
# ...

# %%
#noms des colonnes
raw_data.columns
# Out:
# Index(['id', 'title', 'slug', 'url', 'organization', 'organization_id',
#        'description', 'frequency', 'license', 'temporal_coverage.start',
#        'temporal_coverage.end', 'spatial.granularity', 'spatial.zones',
#        'private', 'featured', 'created_at', 'last_modified', 'tags',
#        'metric.nb_uniq_visitors', 'metric.views', 'metric.followers',
#        'metric.reuses', 'metric.nb_visits', 'metric.discussions',
#        'metric.nb_hits', 'metric.issues'],
#       dtype='object')

# %% [markdown]
# #### Conservation des colonnes 'title', 'frequency' et 'metric.views'

# %%
data= raw_data[ ['title', 'frequency', 'metric.views'] ]

# %%
data
# Out:
#                                                 title   frequency  \
# 0   Indices annuels de précipitations et nombre de...    punctual
# 1   Indices saisonniers de température et nombre d...    punctual
# 2   Indices annuels de température et nombre de jo...    punctual
# 3   Indices mensuels d'anomalie de température et ...    punctual
# 4   Données horaires des 55 stations terrestres de...    punctual
# 5   Indices saisonniers de précipitations et nombr...    punctual
# 6   Indices annuels d'anomalie de précipitations e...    punctual
# 7   Prévisions du modèle de vagues MFWAM sur la zo...    punctual
# 8    Données d'observation en mer (bouées et bateaux)  continuous
# 9   Données du modèle atmosphérique AROME à aire l...  continuous
# 10  #HackRisques Episode de vent fort sur la régio...    punctual
# 11  Diffusion "temps réel" de la vigilance météoro...  continuous
# 12  Indices saisonniers d'anomalie de précipitatio...    punctual
# ...
